# %% [markdown]
# # Emission AI
#
# #### Microsoft AI for Earth Project
# AI Monitoring Coal-fired Power Plant Emission from Space
# #### Team Members
# Ziheng Sun, Zack Chester, Daniel Tong
# #### Date
# 4/30/2020-4/30/2021
# #### Abstract
# The goal is to build a reusable machine learning model to estimate the emission of coal-fired power plants by satellite observations. The machine learning model will be trained on the monitoring data of the power plants collected from EPA eGRID, and the remote sensed datasets of TROPOMI on Sentinel 5 Precursor and the meterological observations from MERRA.
#
# The model will take remote sensing records as inputs, and output an estimated NOX emission daily volume.

# %% [markdown]
# ### Step 1: Read CSV
#
# The demo CSV files are located in the folder `data`. The CSV initially contains six columns: Facility ID (EPA Code of PP), Latitude, Longitude, Date, EPA Daily NO2 divided by 1e+05, TROPOMI NO2_column_number_density (Total vertical column of NO2, ratio of the slant column density of NO2 and the total air mass factor). Both [EPA](https://www.epa.gov/egrid), [TROPOMI](http://www.tropomi.eu/) and [MERRA](https://gmao.gsfc.nasa.gov/reanalysis/MERRA/) datasets can be accessed and retrieval free of charge.
#
# One preprocessing step is to turn the date column into three separate columns as the machine learning cannot parse date strings as input. It need be turned into numeric values. We transform the date column into dayofweek, dayofmonth, and dayofyear. The original date column is excluded from the training dataset to pass the data type checker.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # Plotting and Visualizing data
from sklearn.model_selection import train_test_split
import os
print(os.listdir("data"))

# Describe the data, and get a overview
data = pd.read_csv('data/tropomi_epa_kvps_NO2_2019_56.csv',parse_dates=["Date"])

print("==================>")
print(data.describe())

data['dayofyear'] = data['Date'].dt.dayofyear
data['dayofweek'] = data['Date'].dt.dayofweek
data['dayofmonth'] = data['Date'].dt.day
data = data.drop(columns=["Date"])

print("==================>")
print(data.columns)

# Separating dependednt & Indepented Variables 
x = data.iloc[:, data.columns != 'EPA_NO2/100000'].values
y = data.iloc[:, data.columns == 'EPA_NO2/100000']

# show the shape of x and y to make sure they have the same length

# Train Test Split at ratio 0.33
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33)

y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

y_train = y_train.ravel()
y_test = y_test.ravel()

print("===================>")
print("X_train's shape: ", x_train.shape)
print("y_train's shape: ", y_train.shape)
print("x_test's shape: ", x_test.shape)
print("y_test's shape: ", y_test.shape)

# print(y_test)
# print(y_train)
# Out:
# ['tropomi_epa_kvps_NO2_2018_56.csv', 'tropomi_epa_kvps_NO2_2019_56.csv']
# ==================>
#          FID      Latitude     Longitude  EPA_NO2/100000  TROPOMI*1000  \
# count  167.0  1.670000e+02  1.670000e+02      167.000000    167.000000
# mean    56.0  3.148802e+01 -8.791075e+01        0.202637      0.073023
# std      0.0  1.425359e-14  8.552157e-14        0.095789      0.017048
# min     56.0  3.148802e+01 -8.791075e+01        0.000180      0.038700
# 25%     56.0  3.148802e+01 -8.791075e+01        0.142335      0.061850
# 50%     56.0  3.148802e+01 -8.791075e+01        0.202720      0.069900
# 75%     56.0  3.148802e+01 -8.791075e+01        0.242405      0.081050
# max     56.0  3.148802e+01 -8.791075e+01        0.459370      0.127100
#
#        Wind (Monthly)  Temp (Monthly)  Precip (Monthly)  \
# count      167.000000      167.000000        167.000000
# mean         3.871367      292.725567          0.000052
# std          0.367921        7.072844          0.000026
# min          3.383229      281.632294          0.000004
# 25%          3.605924      284.216461          0.000047
# 50%          3.678730      294.809784          0.000047
# 75%          4.234426      299.535797          0.000074
# max          4.602291      301.860596          0.000098
#
#        Cloud Fraction (Monthly)
# count                167.000000
# mean                   0.509011
# std                    0.048822
# min                    0.359887
# 25%                    0.486571
# 50%                    0.525576
# 75%                    0.526714
# max                    0.691063
# ==================>
# Index(['FID', 'Latitude', 'Longitude', 'EPA_NO2/100000', 'TROPOMI*1000',
#        'Wind (Monthly)', 'Temp (Monthly)', 'Precip (Monthly)',
#        'Cloud Fraction (Monthly)', 'dayofyear', 'dayofweek', 'dayofmonth'],
#       dtype='object')
# ===================>
# X_train's shape:  (111, 11)
# y_train's shape:  (111,)
# x_test's shape:  (56, 11)
# y_test's shape:  (56,)

# %% [markdown]
# ### Step 2: Train Deep Learning model
#
# The hyperparameter tuning is a very troublesome task. Use Keras tensorflow model.

# %%
# Model Import and Build
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


model = keras.Sequential(
    [
        keras.Input(shape=(11)),
        layers.Dense(500, activation="relu"),
        layers.Dense(500, activation="relu"),
        layers.Dense(500, activation="relu"),
        layers.Dense(500, activation="relu"),
        layers.Dense(500, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
        
    ]
)  # No weights at this stage!

# Call the model on a test input
# x = tf.ones((1, 4))
# y = model(x)
print("Number of weights after calling the model:", len(model.weights))  # 6

model.summary()
model.compile(optimizer="Adadelta", loss="mse", metrics=[
                       tf.keras.metrics.mean_squared_error])

model.fit(x_train, y_train, batch_size=16, epochs=100)
# Out:
# Number of weights after calling the model: 12
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_110 (Dense)            (None, 500)               6000
# _________________________________________________________________
# dense_111 (Dense)            (None, 500)               250500
# _________________________________________________________________
# dense_112 (Dense)            (None, 500)               250500
# _________________________________________________________________
# dense_113 (Dense)            (None, 500)               250500
# _________________________________________________________________
# dense_114 (Dense)            (None, 500)               250500
# _________________________________________________________________
# dense_115 (Dense)            (None, 1)                 501
# =================================================================
# Total params: 1,008,501
# Trainable params: 1,008,501
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5974 - mean_squared_error: 0.5974 - mean_absolute_error: 0.7668 - mean_absolute_percentage_error: 7673.8672
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5184 - mean_squared_error: 0.5184 - mean_absolute_error: 0.7117 - mean_absolute_percentage_error: 7430.9385
# Epoch 3/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2060 - mean_squared_error: 0.2060 - mean_absolute_error: 0.4045 - mean_absolute_percentage_error: 4988.3506
# Epoch 4/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0317 - mean_squared_error: 0.0317 - mean_absolute_error: 0.1400 - mean_absolute_percentage_error: 2854.7185
# Epoch 5/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - mean_absolute_error: 0.1076 - mean_absolute_percentage_error: 2160.4675
# Epoch 6/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - mean_absolute_error: 0.0968 - mean_absolute_percentage_error: 1944.5302
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0917 - mean_absolute_percentage_error: 1826.6093
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0885 - mean_absolute_percentage_error: 1813.2408
# Epoch 9/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0859 - mean_absolute_percentage_error: 1740.8210
# Epoch 10/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0834 - mean_absolute_percentage_error: 1760.5790
# Epoch 11/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - mean_absolute_error: 0.0818 - mean_absolute_percentage_error: 1765.9451
# Epoch 12/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - mean_absolute_error: 0.0801 - mean_absolute_percentage_error: 1713.5861
# Epoch 13/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - mean_absolute_error: 0.0791 - mean_absolute_percentage_error: 1681.1473
# Epoch 14/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - mean_absolute_error: 0.0780 - mean_absolute_percentage_error: 1657.0145
# Epoch 15/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - mean_absolute_error: 0.0769 - mean_absolute_percentage_error: 1664.2052
# Epoch 16/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - mean_absolute_error: 0.0762 - mean_absolute_percentage_error: 1624.2646
# Epoch 17/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - mean_absolute_error: 0.0752 - mean_absolute_percentage_error: 1641.4696
# Epoch 18/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - mean_absolute_error: 0.0747 - mean_absolute_percentage_error: 1605.8217
# Epoch 19/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - mean_absolute_error: 0.0744 - mean_absolute_percentage_error: 1644.3160
# Epoch 20/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - mean_absolute_error: 0.0733 - mean_absolute_percentage_error: 1602.9979
# Epoch 21/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - mean_absolute_error: 0.0733 - mean_absolute_percentage_error: 1639.1932
# Epoch 22/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - mean_absolute_error: 0.0728 - mean_absolute_percentage_error: 1595.3999
# Epoch 23/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0723 - mean_absolute_percentage_error: 1584.3079
# Epoch 24/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0722 - mean_absolute_percentage_error: 1636.7805
# Epoch 25/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0716 - mean_absolute_percentage_error: 1562.7715
# Epoch 26/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0722 - mean_absolute_percentage_error: 1600.5819
# Epoch 27/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0709 - mean_absolute_percentage_error: 1624.5267
# Epoch 28/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - mean_absolute_error: 0.0712 - mean_absolute_percentage_error: 1579.9948
# Epoch 29/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0705 - mean_absolute_percentage_error: 1584.7767
# Epoch 30/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0706 - mean_absolute_percentage_error: 1588.7264
# Epoch 31/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - mean_absolute_error: 0.0702 - mean_absolute_percentage_error: 1632.2366
# Epoch 32/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0702 - mean_absolute_percentage_error: 1650.4824
# Epoch 33/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0697 - mean_absolute_percentage_error: 1565.8188
# Epoch 34/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0692 - mean_absolute_percentage_error: 1627.8395
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0691 - mean_absolute_percentage_error: 1619.4952
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0684 - mean_absolute_percentage_error: 1521.5991
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0679 - mean_absolute_percentage_error: 1621.4510
# Epoch 38/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0700 - mean_absolute_percentage_error: 1630.2916
# Epoch 39/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0684 - mean_absolute_percentage_error: 1574.2511
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0682 - mean_absolute_percentage_error: 1596.0828
# Epoch 41/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0677 - mean_absolute_percentage_error: 1630.2391
# Epoch 42/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0678 - mean_absolute_percentage_error: 1611.4080
# Epoch 43/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0675 - mean_absolute_percentage_error: 1526.3306
# Epoch 44/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0678 - mean_absolute_percentage_error: 1534.1147
# Epoch 45/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0667 - mean_absolute_percentage_error: 1660.1616
# Epoch 46/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0669 - mean_absolute_percentage_error: 1572.3584
# Epoch 47/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0680 - mean_absolute_percentage_error: 1682.1189
# Epoch 48/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0670 - mean_absolute_percentage_error: 1566.6143
# Epoch 49/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0664 - mean_absolute_percentage_error: 1467.7291
# Epoch 50/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0666 - mean_absolute_percentage_error: 1578.1801
# Epoch 51/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0668 - mean_absolute_percentage_error: 1647.1160
# Epoch 52/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0659 - mean_absolute_percentage_error: 1605.8247
# Epoch 53/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0672 - mean_absolute_percentage_error: 1562.9963
# Epoch 54/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0679 - mean_absolute_percentage_error: 1590.0558
# Epoch 55/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0663 - mean_absolute_percentage_error: 1523.4452
# Epoch 56/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0662 - mean_absolute_percentage_error: 1650.4534
# Epoch 57/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0675 - mean_absolute_percentage_error: 1613.1035
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0667 - mean_absolute_percentage_error: 1602.2454
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0672 - mean_absolute_percentage_error: 1561.9302
# Epoch 60/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0658 - mean_absolute_percentage_error: 1564.1565
# Epoch 61/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0657 - mean_absolute_percentage_error: 1588.0812
# Epoch 62/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0661 - mean_absolute_percentage_error: 1651.4816
# Epoch 63/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0656 - mean_absolute_percentage_error: 1539.4991
# Epoch 64/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0658 - mean_absolute_percentage_error: 1651.1351
# Epoch 65/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0659 - mean_absolute_percentage_error: 1582.3940
# Epoch 66/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0659 - mean_absolute_percentage_error: 1549.3232
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0658 - mean_absolute_percentage_error: 1582.7167
# Epoch 68/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0649 - mean_absolute_percentage_error: 1686.2296
# Epoch 69/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0646 - mean_absolute_percentage_error: 1552.1581
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0657 - mean_absolute_percentage_error: 1610.5192
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0656 - mean_absolute_percentage_error: 1525.9994
# Epoch 72/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0666 - mean_absolute_percentage_error: 1539.2754
# Epoch 73/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0645 - mean_absolute_percentage_error: 1635.1392
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0652 - mean_absolute_percentage_error: 1495.1049
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0645 - mean_absolute_percentage_error: 1605.6177
# Epoch 76/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0648 - mean_absolute_percentage_error: 1634.0386
# Epoch 77/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0649 - mean_absolute_percentage_error: 1477.1412
# Epoch 78/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0647 - mean_absolute_percentage_error: 1712.7231
# Epoch 79/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0643 - mean_absolute_percentage_error: 1632.9198
# Epoch 80/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0658 - mean_absolute_percentage_error: 1489.0699
# Epoch 81/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0646 - mean_absolute_percentage_error: 1580.7112
# Epoch 82/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0638 - mean_absolute_percentage_error: 1538.6555
# Epoch 83/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0648 - mean_absolute_percentage_error: 1643.9917
# Epoch 84/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0638 - mean_absolute_percentage_error: 1591.7107
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0653 - mean_absolute_percentage_error: 1618.5065
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0642 - mean_absolute_percentage_error: 1602.5269
# Epoch 87/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0642 - mean_absolute_percentage_error: 1577.8827
# Epoch 88/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0641 - mean_absolute_percentage_error: 1628.1063
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0652 - mean_absolute_percentage_error: 1674.8496
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0645 - mean_absolute_percentage_error: 1629.8778
# Epoch 91/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0635 - mean_absolute_percentage_error: 1621.5983
# Epoch 92/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0640 - mean_absolute_percentage_error: 1550.0010
# Epoch 93/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0637 - mean_absolute_percentage_error: 1661.3542
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0636 - mean_absolute_percentage_error: 1581.0432
# Epoch 95/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0642 - mean_absolute_percentage_error: 1577.1259
# Epoch 96/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0635 - mean_absolute_percentage_error: 1584.5194
# Epoch 97/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0654 - mean_absolute_percentage_error: 1602.4028
# Epoch 98/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0630 - mean_absolute_percentage_error: 1598.2216
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0641 - mean_absolute_percentage_error: 1564.9513
# Epoch 100/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0632 - mean_absolute_percentage_error: 1610.5350

# %% [markdown]
# ### Step 3: Test ML model
#
# Predict on the test dataset using the trained models

# %%
# Use the trained models to make predictions
y_test_pred = model.predict(x_test)

# %% [markdown]
# ### Step 4: Visualize the Results
#
# Visualization of the ML results could facilitate the intercomparison of machine learning models and identify the pros and cons of various models in different groups of data samples.
#
# Blue dots are the true observation of EPA. Black dots are the predicted values of machine learning models.

# %%
def visualizeResults(modelname, x_test, y_test, pred):
    # Visualization
    ## Check the fitting on training set
    plt.scatter(x_test[:,3], y_test, color='blue')
    plt.scatter(x_test[:,3], pred, color='black')
#     plt.scatter(y_test, pred, color='black')
    plt.title(modelname + ' Fit on testing set')
    plt.xlabel('TROMPOMI-Test')
    plt.ylabel('EPA-Test')
    plt.show()
    
visualizeResults("Neural Network", x_test, y_test, y_test_pred)

# %% [markdown]
# ### Step 5: Calculate quantitative metrics
#
# For a regression task, the accuracy metrics are normally mean squared error (MSE), mean absolute error (MAE), and coefficient of determination (R2).

# %%
from sklearn.metrics import accuracy_score
from sklearn import metrics

def showAccuracyMetrics(mlmethod, model, y_test, y_pred):
    print("Model ", mlmethod, " Performance:")
#     print(y_test.shape, y_pred.shape)
    
    mae = metrics.mean_absolute_error(y_test, y_pred)
    mse = metrics.mean_squared_error(y_test, y_pred)
    r2 = metrics.r2_score(y_test, y_pred)
    print("   MAE: ", mae)
    print("   MSE: ", mse)
    print("   R2: ", r2)
    
# print(y_test, linear_pred)

showAccuracyMetrics("Neural Network: ", model, y_test, y_test_pred)
# Out:
# Model  Neural Network:   Performance:
#    MAE:  0.07036026528682027
#    MSE:  0.009494947684429626
#    R2:  -0.09887729192323125

# %% [markdown]
# ### Step 6: Feature Importance
#
# 0 - 'FID',
#
# 1 - 'Latitude',
#
# 2 - 'Longitude',
#
# 3 - 'TROPOMI*1000',
#
# 4 - 'Wind (Monthly)',
#
# 5 - 'Temp (Monthly)',
#
# 6 - 'Precip (Monthly)',
#
# 7 - 'Cloud Fraction (Monthly)',
#
# 8 - 'dayofyear',
#
# 9 - 'dayofweek',
#
# 10 - 'dayofmonth'

# %%
def showImportance(model):
    labels = ['FID', 'Latitude', 'Longitude', 'TROPOMI*1000',\
       'Wind (Monthly)', 'Temp (Monthly)', 'Precip (Monthly)',\
       'Cloud Fraction (Monthly)', 'dayofyear', 'dayofweek', 'dayofmonth']
    # get importance
    importance = model.best_estimator_.feature_importances_
    print(len(labels))
    print(importance)
    # summarize feature importance
    for i,v in enumerate(importance):
        print('Feature: %s, Score: %.5f' % (labels[i],v))
    # plot feature importance
    plt.bar([x for x in range(len(importance))], importance)
    plt.show()
    
# showImportance(rf_regressor)

# %% [markdown]
# ### Conclusion
#
# This notebook shows how to use machine learning models to predict the emission of coal-fired power plants using satellite observations like TROPOMI and meteorology observations from MERRA.
#
# The results show that random forest and voting ensemble models are similar in the performance. The random forest model has a slightly better performance in this case. That is also because the ensembled model is from the trained linear regression and the random forest models. The results are basically an average between the two models' results.
#
# Linear regression model outputs basically the values in a narrow range regarless of the variances in the TROPOMI observation and never produce the values greater than 0.3 or less than 0.1. It is not suitable for this prediction.
#
# ##### Final Remarks
#
# Using machine learning to predict ground emission from remote sensed data is possible. More improvements are needed to ensure the accuracy, generality, and stability of the trained models in a long-term operational run. The demonstrated power plant site is in the rural area in Alabama and there is less NO2 emission sources other than the power plant itself. More research is required to make it work for those power plants located in or nearby urban regions, where other emission sources may dominate the NOX in the atmosphere.

# %% [markdown]
# ### Citation
#
# Please cite this work as:
#
# `Sun, Ziheng, Zack Chester, and Daniel Tong. 2021. "EmissionAI: Ai Monitoring Coal-Fired Power Plant Emission from Space."  https://github.com/ZihengSun/EmissionAI  `
